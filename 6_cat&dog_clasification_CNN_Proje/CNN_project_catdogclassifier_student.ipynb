# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>

# %%
# import libraries

# %%
import os
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from sklearn.model_selection import train_test_split
from keras import optimizers
from keras.preprocessing import image
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
import seaborn as sns

# %% [markdown]
# The Dogs vs. Cats dataset is a common computer vision dataset in which pictures are classified as either including a dog or a cat.
#
# After the dataset is well studied, it can be used to understand and practice how to design, evaluate, and apply convolutional neural networks for image classification.
#
# You will build a classifier with images and try to detect dogs versus cats using CNN.
#
# Train set includes 12500 cat-5026 dog images, validation set includes 1219 cat-1071 dog images and test set incgludes 6897 cat and dogs images together.

# %%
# read data and check how many class in train set

# %%
pwd
# Out:
# 'C:\\Users\\MT\\Desktop\\2- DL\\Proje_Ödev\\CNN_Proje'

# %%
my_data_dir = 'C:\\Users\\MT\\Desktop\\2- DL\\Proje_Ödev\\CNN_Proje\data'

# %%
os.listdir(my_data_dir)
# Out:
# ['test', 'train', 'validation']

# %%
test_path = my_data_dir+'/test/'
train_path = my_data_dir+'/train/'
validation_path = my_data_dir+'/validation/'

# %%
os.listdir(train_path)
# Out:
# ['cat', 'dog']

# %%
os.listdir(validation_path)
# Out:
# ['cat', 'dog']

# %%
os.listdir(test_path)
# Out:
# ['10000.jpg',
#  '10001.jpg',
#  '10002.jpg',
#  '10003.jpg',
#  '10004.jpg',
#  '10005.jpg',
#  '10006.jpg',
#  '10007.jpg',
#  '10008.jpg',
#  '10009.jpg',
#  '10010.jpg',
#  '10011.jpg',
#  '10012.jpg',
#  '10013.jpg',
#  '10014.jpg',
#  '10015.jpg',
#  '10016.jpg',
#  '10017.jpg',
#  '10018.jpg',
#  '10019.jpg',
#  '10020.jpg',
#  '10021.jpg',
#  '10022.jpg',
#  '10023.jpg',
#  '10024.jpg',
#  '10025.jpg',
#  '10026.jpg',
#  '10027.jpg',
#  '10028.jpg',
#  '10029.jpg',
#  '10030.jpg',
#  '10031.jpg',
#  '10032.jpg',
#  '10033.jpg',
#  '10034.jpg',
#  '10035.jpg',
#  '10036.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10039.jpg',
#  '10040.jpg',
#  '10041.jpg',
#  '10042.jpg',
#  '10043.jpg',
#  '10044.jpg',
#  '10045.jpg',
#  '10046.jpg',
#  '10047.jpg',
#  '10048.jpg',
#  '10049.jpg',
#  '10050.jpg',
#  '10051.jpg',
#  '10052.jpg',
#  '10053.jpg',
#  '10054.jpg',
#  '10055.jpg',
#  '10056.jpg',
#  '10057.jpg',
#  '10058.jpg',
#  '10059.jpg',
#  '10060.jpg',
#  '10061.jpg',
#  '10062.jpg',
#  '10063.jpg',
#  '10064.jpg',
#  '10065.jpg',
#  '10066.jpg',
#  '10067.jpg',
#  '10068.jpg',
#  '10069.jpg',
#  '10070.jpg',
#  '10071.jpg',
#  '10072.jpg',
#  '10073.jpg',
#  '10074.jpg',
#  '10075.jpg',
#  '10076.jpg',
#  '10077.jpg',
#  '10078.jpg',
#  '10079.jpg',
#  '10080.jpg',
#  '10081.jpg',
#  '10082.jpg',
#  '10083.jpg',
#  '10925.jpg',
#  '10926.jpg',
#  '10927.jpg',
#  '10928.jpg',
#  '10929.jpg',
#  '10930.jpg',
#  '10931.jpg',
#  '10932.jpg',
#  '10933.jpg',
#  '10934.jpg',
#  '10935.jpg',
#  '10936.jpg',
#  '10937.jpg',
#  '10938.jpg',
#  '10939.jpg',
#  '10940.jpg',
#  '10941.jpg',
#  '10942.jpg',
#  '10943.jpg',
#  '10944.jpg',
#  '10945.jpg',
#  '10946.jpg',
#  '10947.jpg',
#  '10948.jpg',
#  '10949.jpg',
#  '10950.jpg',
#  '10951.jpg',
#  '10952.jpg',
#  '10953.jpg',
#  '10954.jpg',
#  '10955.jpg',
#  '10956.jpg',
#  '10957.jpg',
#  '10958.jpg',
#  '10959.jpg',
#  '10960.jpg',
#  '10961.jpg',
#  '10962.jpg',
#  '10963.jpg',
#  '10964.jpg',
#  '10965.jpg',
#  '10966.jpg',
#  '10967.jpg',
#  '10968.jpg',
#  '10969.jpg',
#  '10970.jpg',
#  '10971.jpg',
#  '10972.jpg',
#  '10973.jpg',
#  '10974.jpg',
#  '10975.jpg',
#  '10976.jpg',
#  '10977.jpg',
#  '10978.jpg',
#  '10979.jpg',
#  '10980.jpg',
#  '10981.jpg',
#  '10982.jpg',
#  '10983.jpg',
#  '10984.jpg',
#  '10985.jpg',
#  '10986.jpg',
#  '10987.jpg',
#  '10988.jpg',
#  '10989.jpg',
#  '10990.jpg',
#  '10991.jpg',
#  '10992.jpg',
#  '10993.jpg',
#  '10994.jpg',
#  '10995.jpg',
#  '10996.jpg',
#  '10997.jpg',
#  '10998.jpg',
#  '10999.jpg',
#  ...]

# %% [markdown]
#  ## cat

# %%
os.listdir(train_path+'cat')[100]
# Out:
# 'cat.10087.jpg'

# %%
cat_img = train_path+'cat'+'/cat.10087.jpg'

# %%
imread(cat_img)
# Out:
# array([[[109,  94,  75],
#         [115, 100,  81],
#         [126, 111,  92],
#         ...,
#         [ 36,  34,  21],
#         [ 36,  34,  21],
#         [ 36,  34,  21]],
#
#        [[110,  95,  76],
#         [110,  95,  76],
#         [115, 100,  81],
#         ...,
#         [ 35,  33,  21],
#         [ 35,  33,  20],
#         [ 35,  33,  20]],
#
#        [[114,  99,  80],
#         [109,  94,  75],
#         [107,  92,  73],
#         ...,
#         [ 34,  32,  20],
#         [ 34,  32,  20],
#         [ 34,  32,  20]],
#
#        ...,
#
#        [[176, 141, 111],
#         [212, 177, 145],
#         [206, 171, 139],
#         ...,
#         [239, 188, 123],
#         [241, 190, 125],
#         [237, 186, 121]],
#
#        [[176, 141, 111],
#         [212, 177, 145],
#         [206, 171, 139],
#         ...,
#         [239, 188, 123],
#         [241, 190, 125],
#         [238, 187, 122]],
#
#        [[176, 141, 111],
#         [212, 177, 145],
#         [206, 171, 139],
#         ...,
#         [239, 188, 123],
#         [241, 190, 125],
#         [238, 187, 122]]], dtype=uint8)

# %%
cat_img= imread(cat_img)

# %%
plt.imshow(cat_img)

# %%
cat_img.shape
# Out:
# (299, 350, 3)

# %% [markdown]
# ## dog

# %%
os.listdir(train_path+'dog')[500]
# Out:
# 'dog.10295.jpg'

# %%
dog_img = train_path+'dog'+'/dog.10295.jpg'

# %%
imread(dog_img)
# Out:
# array([[[ 86,  86,  62],
#         [ 85,  85,  61],
#         [ 85,  85,  61],
#         ...,
#         [121, 120,  99],
#         [119, 121,  99],
#         [120, 122, 100]],
#
#        [[ 85,  85,  61],
#         [ 84,  84,  60],
#         [ 84,  84,  60],
#         ...,
#         [122, 121, 100],
#         [120, 122, 100],
#         [121, 123, 101]],
#
#        [[ 88,  88,  64],
#         [ 87,  87,  63],
#         [ 86,  85,  64],
#         ...,
#         [124, 123, 102],
#         [122, 124, 103],
#         [122, 124, 103]],
#
#        ...,
#
#        [[155, 145, 143],
#         [156, 146, 144],
#         [156, 146, 144],
#         ...,
#         [ 83,  77,  61],
#         [ 82,  76,  60],
#         [ 82,  76,  60]],
#
#        [[154, 145, 140],
#         [155, 146, 141],
#         [155, 145, 143],
#         ...,
#         [ 77,  74,  57],
#         [ 76,  73,  56],
#         [ 75,  72,  55]],
#
#        [[151, 144, 138],
#         [152, 145, 139],
#         [153, 146, 140],
#         ...,
#         [ 76,  73,  56],
#         [ 74,  71,  54],
#         [ 73,  70,  53]]], dtype=uint8)

# %%
plt.imshow(imread(dog_img))

# %% [markdown]
# **Let's check how many images there are.**

# %%
len(os.listdir(train_path+'cat'))
# Out:
# 12500

# %%
len(os.listdir(train_path+'dog'))
# Out:
# 5026

# %%
#take cat image at index 0 from train set
#take dog image at index 1 from train set
#compare their shapes

# %%
os.listdir(train_path+'cat')[0]
# Out:
# 'cat.0.jpg'

# %%
cat_0 = train_path+'cat'+'/cat.0.jpg'

# %%
cat_0 = imread(cat_0)

# %%
plt.imshow(cat_0)

# %%
os.listdir(train_path+'dog')[0]
# Out:
# '2462.jpg'

# %%
#train_path+'dog'+'/dog.2462.jpg'

# %%
#imread('C:\\Users\\MT\\Desktop\\2- DL\\Proje_Ödev\\CNN_Proje\\data/train/dog/dog.2462.jpg')

# %%
#plt.imshow(imread('C:\\Users\\MT\\Desktop\\2- DL\\Proje_Ödev\\CNN_Proje\\data/train/dog/dog.2462.jpg'))

# %%
dog_0 = train_path+'dog'+'/dog.2462.jpg'

# %%
imread(dog_0)
# Out:
# array([[[220, 205, 198],
#         [217, 202, 195],
#         [211, 196, 189],
#         ...,
#         [154, 162, 164],
#         [166, 174, 176],
#         [164, 172, 174]],
#
#        [[219, 204, 197],
#         [216, 201, 194],
#         [211, 196, 189],
#         ...,
#         [156, 162, 162],
#         [169, 175, 175],
#         [167, 173, 173]],
#
#        [[219, 204, 197],
#         [216, 201, 194],
#         [211, 196, 189],
#         ...,
#         [158, 164, 164],
#         [171, 177, 177],
#         [170, 176, 176]],
#
#        ...,
#
#        [[226, 220, 220],
#         [223, 217, 217],
#         [220, 214, 214],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[227, 221, 221],
#         [224, 218, 218],
#         [221, 215, 215],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[228, 222, 222],
#         [225, 219, 219],
#         [222, 216, 216],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
dog_0 = imread(dog_0)

# %%
plt.imshow(dog_0)

# %% [markdown]
# **Let's decide on the final dimension of these images.**

# %%
cat_0.shape
# Out:
# (374, 500, 3)

# %%
dog_0.shape
# Out:
# (470, 499, 3)

# %%
 x= []
y = []
for image in os.listdir(test_path):
    
    img = imread(test_path+image)
    d1,d2,colors = img.shape
    x.append(d1)
    y.append(d2)

# %%
y
# Out:
# [467,
#  499,
#  500,
#  500,
#  488,
#  249,
#  499,
#  500,
#  499,
#  489,
#  500,
#  400,
#  335,
#  470,
#  500,
#  500,
#  240,
#  250,
#  434,
#  499,
#  199,
#  396,
#  500,
#  360,
#  303,
#  443,
#  499,
#  320,
#  200,
#  319,
#  479,
#  274,
#  499,
#  499,
#  406,
#  310,
#  499,
#  499,
#  499,
#  388,
#  499,
#  499,
#  499,
#  350,
#  499,
#  500,
#  448,
#  499,
#  472,
#  407,
#  499,
#  400,
#  375,
#  499,
#  180,
#  375,
#  400,
#  438,
#  500,
#  500,
#  264,
#  473,
#  413,
#  425,
#  399,
#  323,
#  499,
#  499,
#  353,
#  499,
#  500,
#  334,
#  402,
#  500,
#  360,
#  500,
#  416,
#  364,
#  344,
#  375,
#  260,
#  500,
#  499,
#  235,
#  408,
#  350,
#  374,
#  360,
#  499,
#  499,
#  300,
#  399,
#  416,
#  233,
#  249,
#  448,
#  377,
#  499,
#  350,
#  321,
#  360,
#  160,
#  176,
#  499,
#  287,
#  499,
#  499,
#  500,
#  165,
#  374,
#  132,
#  239,
#  374,
#  499,
#  500,
#  468,
#  500,
#  376,
#  499,
#  392,
#  500,
#  353,
#  349,
#  400,
#  413,
#  216,
#  499,
#  500,
#  500,
#  342,
#  500,
#  500,
#  374,
#  247,
#  499,
#  192,
#  400,
#  499,
#  319,
#  456,
#  475,
#  125,
#  500,
#  499,
#  258,
#  499,
#  225,
#  500,
#  500,
#  499,
#  200,
#  374,
#  455,
#  327,
#  405,
#  499,
#  435,
#  500,
#  249,
#  499,
#  160,
#  478,
#  374,
#  500,
#  400,
#  500,
#  351,
#  499,
#  222,
#  500,
#  449,
#  499,
#  374,
#  429,
#  299,
#  500,
#  431,
#  487,
#  299,
#  229,
#  495,
#  500,
#  326,
#  500,
#  300,
#  500,
#  383,
#  500,
#  312,
#  500,
#  465,
#  249,
#  500,
#  320,
#  257,
#  500,
#  500,
#  460,
#  193,
#  350,
#  453,
#  499,
#  267,
#  331,
#  375,
#  500,
#  218,
#  382,
#  500,
#  475,
#  500,
#  500,
#  299,
#  123,
#  319,
#  350,
#  499,
#  500,
#  423,
#  500,
#  440,
#  71,
#  425,
#  299,
#  499,
#  500,
#  251,
#  499,
#  499,
#  499,
#  318,
#  332,
#  499,
#  500,
#  500,
#  427,
#  499,
#  499,
#  500,
#  500,
#  500,
#  400,
#  191,
#  500,
#  448,
#  414,
#  499,
#  357,
#  499,
#  349,
#  452,
#  500,
#  500,
#  349,
#  420,
#  197,
#  500,
#  349,
#  333,
#  375,
#  500,
#  499,
#  500,
#  500,
#  499,
#  499,
#  349,
#  300,
#  257,
#  414,
#  215,
#  349,
#  374,
#  499,
#  350,
#  417,
#  400,
#  500,
#  215,
#  494,
#  350,
#  499,
#  500,
#  364,
#  477,
#  499,
#  375,
#  439,
#  407,
#  499,
#  392,
#  149,
#  480,
#  499,
#  500,
#  349,
#  500,
#  406,
#  321,
#  320,
#  499,
#  500,
#  493,
#  383,
#  120,
#  170,
#  500,
#  499,
#  500,
#  364,
#  500,
#  500,
#  250,
#  149,
#  499,
#  400,
#  499,
#  350,
#  319,
#  499,
#  499,
#  247,
#  400,
#  169,
#  400,
#  499,
#  359,
#  229,
#  316,
#  173,
#  500,
#  414,
#  316,
#  499,
#  396,
#  500,
#  499,
#  500,
#  500,
#  500,
#  349,
#  500,
#  481,
#  500,
#  350,
#  264,
#  416,
#  359,
#  149,
#  225,
#  499,
#  483,
#  500,
#  499,
#  261,
#  500,
#  124,
#  499,
#  432,
#  499,
#  387,
#  500,
#  500,
#  231,
#  149,
#  337,
#  500,
#  251,
#  500,
#  500,
#  499,
#  499,
#  499,
#  499,
#  242,
#  500,
#  350,
#  499,
#  350,
#  384,
#  206,
#  360,
#  448,
#  331,
#  250,
#  359,
#  320,
#  500,
#  500,
#  300,
#  419,
#  499,
#  200,
#  499,
#  387,
#  499,
#  149,
#  299,
#  375,
#  359,
#  316,
#  369,
#  452,
#  209,
#  499,
#  500,
#  149,
#  379,
#  396,
#  384,
#  499,
#  500,
#  394,
#  500,
#  500,
#  499,
#  356,
#  133,
#  499,
#  295,
#  240,
#  499,
#  153,
#  350,
#  423,
#  125,
#  500,
#  500,
#  499,
#  500,
#  499,
#  480,
#  299,
#  259,
#  500,
#  499,
#  256,
#  499,
#  500,
#  257,
#  321,
#  125,
#  361,
#  499,
#  202,
#  441,
#  500,
#  500,
#  359,
#  175,
#  275,
#  500,
#  315,
#  499,
#  451,
#  374,
#  60,
#  319,
#  499,
#  500,
#  499,
#  345,
#  489,
#  487,
#  499,
#  374,
#  359,
#  444,
#  478,
#  115,
#  499,
#  476,
#  500,
#  318,
#  500,
#  500,
#  360,
#  290,
#  420,
#  500,
#  312,
#  341,
#  249,
#  320,
#  231,
#  499,
#  399,
#  499,
#  268,
#  499,
#  500,
#  500,
#  377,
#  499,
#  500,
#  499,
#  500,
#  499,
#  500,
#  467,
#  499,
#  500,
#  467,
#  359,
#  492,
#  375,
#  271,
#  499,
#  499,
#  350,
#  497,
#  499,
#  97,
#  199,
#  391,
#  500,
#  500,
#  348,
#  350,
#  500,
#  497,
#  276,
#  499,
#  500,
#  320,
#  500,
#  300,
#  466,
#  499,
#  499,
#  150,
#  199,
#  500,
#  500,
#  474,
#  500,
#  128,
#  500,
#  500,
#  500,
#  500,
#  249,
#  376,
#  500,
#  499,
#  439,
#  200,
#  498,
#  500,
#  499,
#  334,
#  349,
#  499,
#  344,
#  385,
#  500,
#  375,
#  369,
#  299,
#  491,
#  499,
#  499,
#  281,
#  394,
#  480,
#  500,
#  500,
#  441,
#  357,
#  345,
#  289,
#  299,
#  499,
#  278,
#  500,
#  209,
#  500,
#  499,
#  499,
#  500,
#  199,
#  349,
#  308,
#  499,
#  479,
#  308,
#  350,
#  500,
#  500,
#  425,
#  500,
#  500,
#  478,
#  199,
#  332,
#  499,
#  500,
#  500,
#  447,
#  499,
#  160,
#  374,
#  123,
#  499,
#  499,
#  500,
#  333,
#  439,
#  500,
#  178,
#  431,
#  500,
#  349,
#  499,
#  320,
#  500,
#  375,
#  399,
#  479,
#  500,
#  375,
#  382,
#  500,
#  500,
#  275,
#  500,
#  500,
#  272,
#  299,
#  350,
#  414,
#  382,
#  400,
#  499,
#  376,
#  500,
#  500,
#  150,
#  500,
#  190,
#  500,
#  494,
#  500,
#  499,
#  499,
#  300,
#  70,
#  500,
#  372,
#  374,
#  420,
#  500,
#  500,
#  428,
#  499,
#  500,
#  338,
#  131,
#  300,
#  497,
#  499,
#  228,
#  320,
#  360,
#  500,
#  362,
#  290,
#  383,
#  398,
#  500,
#  300,
#  173,
#  360,
#  203,
#  261,
#  500,
#  372,
#  374,
#  299,
#  399,
#  202,
#  500,
#  321,
#  435,
#  310,
#  499,
#  256,
#  339,
#  280,
#  376,
#  499,
#  499,
#  500,
#  323,
#  499,
#  445,
#  344,
#  499,
#  333,
#  500,
#  499,
#  431,
#  359,
#  499,
#  500,
#  499,
#  499,
#  378,
#  499,
#  186,
#  500,
#  500,
#  315,
#  499,
#  499,
#  199,
#  499,
#  479,
#  410,
#  375,
#  500,
#  281,
#  500,
#  283,
#  438,
#  499,
#  500,
#  500,
#  117,
#  500,
#  499,
#  300,
#  319,
#  269,
#  359,
#  500,
#  341,
#  499,
#  499,
#  74,
#  499,
#  297,
#  500,
#  378,
#  219,
#  500,
#  499,
#  480,
#  500,
#  389,
#  499,
#  500,
#  349,
#  375,
#  500,
#  175,
#  324,
#  169,
#  112,
#  336,
#  480,
#  500,
#  400,
#  499,
#  149,
#  360,
#  500,
#  187,
#  479,
#  499,
#  259,
#  499,
#  448,
#  376,
#  500,
#  500,
#  499,
#  499,
#  399,
#  500,
#  500,
#  500,
#  375,
#  499,
#  350,
#  359,
#  225,
#  253,
#  401,
#  350,
#  218,
#  144,
#  176,
#  350,
#  500,
#  500,
#  500,
#  499,
#  372,
#  360,
#  500,
#  384,
#  370,
#  143,
#  499,
#  499,
#  500,
#  407,
#  399,
#  499,
#  500,
#  500,
#  379,
#  400,
#  500,
#  99,
#  499,
#  500,
#  450,
#  500,
#  125,
#  500,
#  263,
#  500,
#  500,
#  327,
#  374,
#  301,
#  176,
#  500,
#  499,
#  400,
#  277,
#  499,
#  499,
#  499,
#  500,
#  499,
#  499,
#  480,
#  285,
#  500,
#  193,
#  500,
#  356,
#  499,
#  349,
#  348,
#  499,
#  191,
#  349,
#  432,
#  150,
#  170,
#  288,
#  500,
#  431,
#  360,
#  119,
#  499,
#  499,
#  378,
#  500,
#  274,
#  100,
#  384,
#  289,
#  346,
#  499,
#  210,
#  499,
#  499,
#  167,
#  342,
#  500,
#  500,
#  210,
#  444,
#  400,
#  453,
#  287,
#  127,
#  500,
#  478,
#  447,
#  350,
#  499,
#  500,
#  349,
#  340,
#  500,
#  490,
#  481,
#  350,
#  500,
#  486,
#  499,
#  410,
#  499,
#  500,
#  500,
#  499,
#  180,
#  435,
#  349,
#  499,
#  239,
#  215,
#  500,
#  500,
#  291,
#  499,
#  463,
#  499,
#  500,
#  500,
#  387,
#  499,
#  500,
#  499,
#  312,
#  500,
#  499,
#  499,
#  500,
#  400,
#  136,
#  499,
#  249,
#  499,
#  265,
#  499,
#  360,
#  266,
#  499,
#  339,
#  500,
#  400,
#  500,
#  350,
#  300,
#  499,
#  206,
#  374,
#  499,
#  345,
#  409,
#  215,
#  500,
#  500,
#  386,
#  191,
#  349,
#  499,
#  193,
#  500,
#  499,
#  375,
#  329,
#  330,
#  500,
#  273,
#  319,
#  320,
#  499,
#  299,
#  276,
#  186,
#  499,
#  500,
#  409,
#  499,
#  499,
#  432,
#  324,
#  500,
#  500,
#  386,
#  320,
#  398,
#  400,
#  500,
#  479,
#  500,
#  500,
#  205,
#  499,
#  108,
#  500,
#  374,
#  499,
#  334,
#  350,
#  452,
#  199,
#  349,
#  349,
#  320,
#  499,
#  500,
#  ...]

# %%
x
# Out:
# [499,
#  293,
#  374,
#  263,
#  399,
#  227,
#  375,
#  374,
#  375,
#  367,
#  374,
#  345,
#  409,
#  500,
#  374,
#  387,
#  269,
#  293,
#  375,
#  432,
#  200,
#  260,
#  374,
#  269,
#  359,
#  459,
#  375,
#  431,
#  149,
#  414,
#  401,
#  500,
#  371,
#  375,
#  400,
#  458,
#  375,
#  375,
#  466,
#  499,
#  490,
#  437,
#  375,
#  349,
#  400,
#  374,
#  335,
#  375,
#  500,
#  384,
#  378,
#  299,
#  499,
#  307,
#  271,
#  499,
#  299,
#  223,
#  497,
#  456,
#  499,
#  499,
#  392,
#  433,
#  477,
#  499,
#  375,
#  375,
#  400,
#  332,
#  374,
#  500,
#  500,
#  332,
#  269,
#  275,
#  311,
#  500,
#  499,
#  499,
#  239,
#  374,
#  375,
#  270,
#  397,
#  299,
#  500,
#  287,
#  419,
#  375,
#  334,
#  364,
#  335,
#  210,
#  193,
#  500,
#  499,
#  375,
#  499,
#  325,
#  269,
#  191,
#  143,
#  375,
#  448,
#  375,
#  333,
#  374,
#  214,
#  499,
#  144,
#  240,
#  500,
#  375,
#  374,
#  499,
#  374,
#  499,
#  375,
#  500,
#  445,
#  500,
#  500,
#  363,
#  500,
#  138,
#  332,
#  374,
#  384,
#  396,
#  374,
#  335,
#  500,
#  447,
#  481,
#  216,
#  284,
#  375,
#  240,
#  499,
#  499,
#  121,
#  374,
#  375,
#  306,
#  295,
#  245,
#  374,
#  275,
#  332,
#  157,
#  500,
#  499,
#  479,
#  500,
#  375,
#  315,
#  332,
#  250,
#  366,
#  115,
#  358,
#  500,
#  374,
#  299,
#  268,
#  288,
#  375,
#  166,
#  374,
#  337,
#  375,
#  388,
#  500,
#  250,
#  378,
#  499,
#  500,
#  286,
#  173,
#  500,
#  315,
#  269,
#  487,
#  224,
#  374,
#  499,
#  374,
#  235,
#  399,
#  499,
#  245,
#  374,
#  239,
#  499,
#  374,
#  374,
#  499,
#  199,
#  266,
#  500,
#  464,
#  400,
#  300,
#  499,
#  376,
#  270,
#  499,
#  374,
#  357,
#  417,
#  497,
#  195,
#  93,
#  240,
#  303,
#  333,
#  332,
#  499,
#  370,
#  314,
#  90,
#  499,
#  300,
#  375,
#  492,
#  150,
#  344,
#  333,
#  375,
#  240,
#  500,
#  379,
#  374,
#  374,
#  426,
#  375,
#  375,
#  374,
#  374,
#  499,
#  352,
#  266,
#  374,
#  397,
#  500,
#  333,
#  499,
#  375,
#  252,
#  333,
#  374,
#  351,
#  262,
#  499,
#  317,
#  374,
#  233,
#  499,
#  499,
#  332,
#  487,
#  424,
#  374,
#  371,
#  375,
#  233,
#  341,
#  499,
#  479,
#  189,
#  262,
#  500,
#  375,
#  327,
#  425,
#  266,
#  374,
#  219,
#  499,
#  261,
#  427,
#  332,
#  498,
#  499,
#  375,
#  499,
#  447,
#  340,
#  375,
#  335,
#  237,
#  359,
#  325,
#  488,
#  262,
#  374,
#  499,
#  500,
#  239,
#  370,
#  374,
#  500,
#  288,
#  146,
#  133,
#  374,
#  375,
#  402,
#  499,
#  374,
#  374,
#  313,
#  100,
#  375,
#  347,
#  375,
#  261,
#  350,
#  329,
#  375,
#  248,
#  399,
#  199,
#  265,
#  375,
#  240,
#  398,
#  500,
#  231,
#  454,
#  463,
#  499,
#  375,
#  335,
#  329,
#  375,
#  374,
#  354,
#  374,
#  323,
#  374,
#  432,
#  490,
#  261,
#  309,
#  316,
#  217,
#  131,
#  191,
#  424,
#  290,
#  291,
#  375,
#  280,
#  374,
#  118,
#  375,
#  306,
#  375,
#  500,
#  374,
#  374,
#  265,
#  208,
#  499,
#  374,
#  288,
#  374,
#  374,
#  375,
#  375,
#  375,
#  383,
#  300,
#  315,
#  303,
#  375,
#  261,
#  500,
#  243,
#  499,
#  335,
#  212,
#  249,
#  480,
#  479,
#  374,
#  374,
#  299,
#  500,
#  339,
#  299,
#  375,
#  500,
#  375,
#  172,
#  277,
#  499,
#  270,
#  363,
#  362,
#  499,
#  174,
#  375,
#  374,
#  173,
#  434,
#  409,
#  479,
#  385,
#  374,
#  370,
#  374,
#  374,
#  375,
#  500,
#  143,
#  472,
#  412,
#  188,
#  375,
#  128,
#  303,
#  424,
#  148,
#  373,
#  374,
#  375,
#  374,
#  458,
#  359,
#  225,
#  500,
#  492,
#  375,
#  255,
#  375,
#  354,
#  258,
#  399,
#  115,
#  415,
#  375,
#  385,
#  467,
#  399,
#  374,
#  431,
#  222,
#  274,
#  376,
#  240,
#  375,
#  379,
#  500,
#  44,
#  240,
#  375,
#  374,
#  375,
#  500,
#  499,
#  500,
#  375,
#  275,
#  241,
#  500,
#  500,
#  219,
#  375,
#  499,
#  374,
#  400,
#  376,
#  374,
#  268,
#  500,
#  415,
#  374,
#  235,
#  336,
#  333,
#  239,
#  448,
#  375,
#  219,
#  375,
#  499,
#  375,
#  374,
#  374,
#  374,
#  375,
#  333,
#  375,
#  499,
#  300,
#  374,
#  400,
#  375,
#  374,
#  351,
#  270,
#  499,
#  499,
#  239,
#  452,
#  375,
#  261,
#  320,
#  360,
#  100,
#  200,
#  449,
#  331,
#  408,
#  499,
#  312,
#  374,
#  499,
#  225,
#  375,
#  498,
#  239,
#  374,
#  237,
#  435,
#  375,
#  326,
#  148,
#  200,
#  374,
#  374,
#  499,
#  374,
#  174,
#  374,
#  374,
#  374,
#  494,
#  283,
#  500,
#  365,
#  374,
#  299,
#  291,
#  497,
#  379,
#  375,
#  500,
#  292,
#  375,
#  330,
#  384,
#  374,
#  499,
#  499,
#  225,
#  499,
#  437,
#  375,
#  225,
#  469,
#  359,
#  374,
#  399,
#  499,
#  499,
#  442,
#  288,
#  286,
#  375,
#  499,
#  393,
#  348,
#  374,
#  463,
#  375,
#  399,
#  200,
#  298,
#  353,
#  375,
#  460,
#  499,
#  324,
#  374,
#  374,
#  345,
#  397,
#  374,
#  499,
#  321,
#  499,
#  344,
#  333,
#  374,
#  499,
#  418,
#  119,
#  500,
#  93,
#  375,
#  375,
#  374,
#  500,
#  477,
#  374,
#  160,
#  339,
#  332,
#  376,
#  375,
#  500,
#  374,
#  499,
#  404,
#  360,
#  332,
#  499,
#  383,
#  369,
#  374,
#  226,
#  374,
#  374,
#  447,
#  249,
#  349,
#  500,
#  424,
#  385,
#  375,
#  500,
#  382,
#  374,
#  180,
#  374,
#  258,
#  374,
#  324,
#  374,
#  375,
#  375,
#  374,
#  96,
#  374,
#  323,
#  500,
#  455,
#  473,
#  415,
#  499,
#  375,
#  374,
#  335,
#  125,
#  299,
#  499,
#  375,
#  270,
#  239,
#  248,
#  374,
#  500,
#  314,
#  336,
#  500,
#  374,
#  321,
#  300,
#  239,
#  399,
#  372,
#  331,
#  499,
#  500,
#  351,
#  408,
#  269,
#  475,
#  500,
#  500,
#  381,
#  375,
#  315,
#  440,
#  293,
#  500,
#  454,
#  341,
#  374,
#  390,
#  375,
#  299,
#  375,
#  375,
#  500,
#  376,
#  334,
#  371,
#  270,
#  376,
#  374,
#  350,
#  498,
#  358,
#  375,
#  257,
#  374,
#  421,
#  401,
#  375,
#  446,
#  176,
#  375,
#  431,
#  499,
#  499,
#  374,
#  258,
#  328,
#  304,
#  500,
#  375,
#  389,
#  480,
#  110,
#  499,
#  375,
#  245,
#  240,
#  499,
#  283,
#  377,
#  442,
#  375,
#  373,
#  75,
#  404,
#  332,
#  374,
#  366,
#  228,
#  374,
#  375,
#  359,
#  374,
#  499,
#  368,
#  374,
#  326,
#  499,
#  351,
#  287,
#  383,
#  200,
#  199,
#  398,
#  500,
#  349,
#  499,
#  375,
#  150,
#  418,
#  461,
#  299,
#  319,
#  375,
#  297,
#  333,
#  316,
#  429,
#  374,
#  491,
#  375,
#  375,
#  263,
#  348,
#  370,
#  454,
#  499,
#  375,
#  177,
#  480,
#  260,
#  270,
#  500,
#  254,
#  111,
#  232,
#  143,
#  261,
#  374,
#  374,
#  374,
#  375,
#  399,
#  479,
#  472,
#  499,
#  500,
#  109,
#  413,
#  375,
#  438,
#  336,
#  396,
#  375,
#  332,
#  404,
#  470,
#  310,
#  368,
#  101,
#  375,
#  419,
#  449,
#  374,
#  136,
#  374,
#  382,
#  362,
#  374,
#  251,
#  500,
#  337,
#  143,
#  374,
#  476,
#  500,
#  360,
#  375,
#  375,
#  375,
#  374,
#  375,
#  375,
#  359,
#  379,
#  370,
#  111,
#  374,
#  278,
#  375,
#  290,
#  499,
#  375,
#  149,
#  262,
#  287,
#  112,
#  156,
#  359,
#  403,
#  422,
#  500,
#  160,
#  375,
#  375,
#  499,
#  331,
#  477,
#  99,
#  408,
#  345,
#  335,
#  375,
#  225,
#  375,
#  329,
#  124,
#  499,
#  324,
#  494,
#  270,
#  500,
#  372,
#  340,
#  432,
#  160,
#  333,
#  350,
#  499,
#  261,
#  448,
#  374,
#  296,
#  499,
#  374,
#  327,
#  499,
#  412,
#  374,
#  350,
#  375,
#  499,
#  375,
#  374,
#  382,
#  375,
#  299,
#  500,
#  200,
#  457,
#  200,
#  270,
#  374,
#  462,
#  498,
#  332,
#  499,
#  375,
#  374,
#  374,
#  500,
#  375,
#  298,
#  333,
#  410,
#  374,
#  375,
#  375,
#  281,
#  413,
#  199,
#  375,
#  188,
#  361,
#  399,
#  373,
#  261,
#  399,
#  333,
#  478,
#  376,
#  499,
#  335,
#  261,
#  454,
#  375,
#  270,
#  500,
#  375,
#  294,
#  398,
#  216,
#  374,
#  374,
#  499,
#  256,
#  348,
#  375,
#  299,
#  446,
#  375,
#  499,
#  330,
#  239,
#  374,
#  199,
#  332,
#  239,
#  490,
#  270,
#  140,
#  221,
#  332,
#  434,
#  415,
#  375,
#  419,
#  287,
#  321,
#  376,
#  391,
#  301,
#  239,
#  500,
#  480,
#  376,
#  360,
#  345,
#  374,
#  400,
#  375,
#  99,
#  374,
#  499,
#  401,
#  300,
#  299,
#  500,
#  135,
#  231,
#  262,
#  500,
#  375,
#  374,
#  ...]

# %%
sns.scatterplot(x,y)
# Out:
# C:\Users\MT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
np.mean(x)
# Out:
# 360.4836885602436

# %%
np.mean(y)
# Out:
# 404.24619399739015

# %%
# decide on a shape to use it in your model as input shape. you can either use average shape size or try something different. 128*128 is preferred here
image_shape = (128,128,3)

# %%
# help(ImageDataGenerator)

# %% [markdown]
# **Image Manipulation**
#
# We can use the ImageDataGenerator to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. ImageDataGenerator does the followings.
#
# * Accepts a batch of images used for training.
# * Applies a series of random transformations to each image in the batch.
# * Replaces the original batch with randomly transformed batch.
# * Training the CNN on this randomly transformed batch.
#
# The goal of applying data augmentation is to have a more generalized model.

# %%
#use ImageDataGenerator to manipulate the images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=15, 
                               width_shift_range=0.10, 
                               height_shift_range=0.10, 
                               #rescale=1/255, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest')

# %%
plt.imshow(dog_0)

# %%
plt.imshow(image_gen.random_transform(dog_0))

# %%
#show transfromed version of dog image

# %% [markdown]
# ### Generating many manipulated images from a directory
#
#
# flow_from_directory function works with images organized in sub-directories. Your directories should include only one class of images, so one folder per class of images.
#
# main_directory/
#
# ...class_a/
#
# ......a_image_1.jpg
#
# ......a_image_2.jpg
#
# ...class_b/
#
# ......b_image_1.jpg
#
# ......b_image_2.jpg
#
# [bağlantı metni](https://drive.google.com/file/d/1ntiw1WnsWq5en96zRQmWADFxoCKS4DNc/view?usp=sharing)

# %% [markdown]
# image_gen.flow_from_directory(train_path)

# %%
#image_gen.flow_from_directory(val_path)

# %%
#test_path = my_data_dir+'/test/'
#train_path = my_data_dir+'/train/'
#validation_path = my_data_dir+'/validation/'

# %%
image_gen.flow_from_directory(validation_path)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 17526 images belonging to 2 classes.

# %% [markdown]
# # Creating the Model

# %%
#create your CNN model here

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 126, 126, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 128)               1605760
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,662,209
# Trainable params: 1,662,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1605760
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,662,209
# Trainable params: 1,662,209
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
#early_stop =

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=5)

# %%
#batch_size =

# %%
#use image_gen from above and read iamges from train and test set

# %%
#train_image_gen =

# %%
batch_size = 16
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 17526 images belonging to 2 classes.

# %%
#val_image_gen =

# %%
val_image_gen = image_gen.flow_from_directory(validation_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 2290 images belonging to 2 classes.

# %%
#show class indices in train set

# %%
val_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# ## Model Training

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#results = #fit your model using train and validation set
# Out:
# Epoch 1/10
# 1096/1096 [==============================] - 355s 323ms/step - loss: 0.6045 - accuracy: 0.7126 - val_loss: 0.7166 - val_accuracy: 0.5341
# Epoch 2/10
# 1096/1096 [==============================] - 275s 250ms/step - loss: 0.5650 - accuracy: 0.7208 - val_loss: 0.6426 - val_accuracy: 0.6179
# Epoch 3/10
# 1096/1096 [==============================] - 270s 246ms/step - loss: 0.5106 - accuracy: 0.7531 - val_loss: 0.7077 - val_accuracy: 0.6354
# Epoch 4/10
# 1096/1096 [==============================] - 268s 245ms/step - loss: 0.4827 - accuracy: 0.7733 - val_loss: 0.5705 - val_accuracy: 0.7022
# Epoch 5/10
# 1096/1096 [==============================] - 272s 248ms/step - loss: 0.4562 - accuracy: 0.7911 - val_loss: 0.5862 - val_accuracy: 0.6974
# Epoch 6/10
# 1096/1096 [==============================] - 265s 242ms/step - loss: 0.4299 - accuracy: 0.8053 - val_loss: 0.4747 - val_accuracy: 0.7764
# Epoch 7/10
# 1096/1096 [==============================] - 634s 579ms/step - loss: 0.4166 - accuracy: 0.8145 - val_loss: 0.5478 - val_accuracy: 0.7402
# Epoch 8/10
# 1096/1096 [==============================] - 272s 248ms/step - loss: 0.3970 - accuracy: 0.8243 - val_loss: 0.5893 - val_accuracy: 0.7437

# %%
results = model.fit_generator(train_image_gen,epochs=10,
                              validation_data=val_image_gen, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 1096/1096 [==============================] - 946s 861ms/step - loss: 0.7122 - accuracy: 0.7092 - val_loss: 0.7498 - val_accuracy: 0.5323
# Epoch 2/10
# 1096/1096 [==============================] - 707s 645ms/step - loss: 0.6009 - accuracy: 0.7132 - val_loss: 0.7559 - val_accuracy: 0.5323
# Epoch 3/10
# 1096/1096 [==============================] - 615s 561ms/step - loss: 0.5997 - accuracy: 0.7132 - val_loss: 0.7601 - val_accuracy: 0.5323
# Epoch 4/10
# 1096/1096 [==============================] - 600s 548ms/step - loss: 0.6004 - accuracy: 0.7132 - val_loss: 0.7590 - val_accuracy: 0.5323
# Epoch 5/10
# 1096/1096 [==============================] - 612s 558ms/step - loss: 0.6017 - accuracy: 0.7132 - val_loss: 0.7690 - val_accuracy: 0.5323
# Epoch 6/10
# 1096/1096 [==============================] - 609s 556ms/step - loss: 0.6014 - accuracy: 0.7129 - val_loss: 0.7600 - val_accuracy: 0.5323

# %% [markdown]
# # Evaluating the Model

# %%
losses = pd.DataFrame(......)

# %%
losses = pd.DataFrame(model.history.history)
losses.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.712158  0.709232  0.749774      0.532314
# 1  0.600870  0.713169  0.755912      0.532314
# 2  0.599702  0.713226  0.760090      0.532314
# 3  0.600419  0.713169  0.758994      0.532314
# 4  0.601660  0.713226  0.768979      0.532314

# %%
plt.figure(figsize=(10,6))
plt.plot(losses.loss, label="loss")
plt.plot(losses.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
plt.plot(losses.accuracy, label="accuracy")
plt.plot(losses.val_accuracy, label="val_accuracy")
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
# Out:
# ['loss', 'accuracy']

# %%
model.evaluate_generator(val_image_gen)
# Out:
# [0.7600348591804504, 0.5323144197463989]

# %%
# Out:
# [0.5973725318908691, 0.7532750964164734]

# %%
from tensorflow.keras.preprocessing import image

# %%
pred_probabilities = model.predict_generator(val_image_gen)

# %%
pred_probabilities =

# %%
pred_probabilities
# Out:
# array([[0.29139522],
#        [0.29139522],
#        [0.29139522],
#        ...,
#        [0.29139522],
#        [0.29139522],
#        [0.29139522]], dtype=float32)

# %%
pred_probabilities
# Out:
# array([[0.044494  ],
#        [0.04975203],
#        [0.14317203],
#        ...,
#        [0.97140694],
#        [0.8137139 ],
#        [0.8951267 ]], dtype=float32)

# %%
val_image_gen.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
predictions = pred_probabilities > 0.5

# %%
predictions
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(val_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69      1219
#            1       0.00      0.00      0.00      1071
#
#     accuracy                           0.53      2290
#    macro avg       0.27      0.50      0.35      2290
# weighted avg       0.28      0.53      0.37      2290

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.94      0.80      1219
#            1       0.89      0.52      0.66      1071
#
#     accuracy                           0.75      2290
#    macro avg       0.79      0.73      0.73      2290
# weighted avg       0.78      0.75      0.73      2290

# %%
confusion_matrix(val_image_gen.classes,predictions)
# Out:
# array([[1219,    0],
#        [1071,    0]], dtype=int64)

# %%
# Out:
# array([[1149,   70],
#        [ 509,  562]], dtype=int64)

# %%
from tensorflow.keras.models import load_model
model.save('cat_dog_detector.h5')

# %% [markdown]
# # Predicting on an Image

# %%
from PIL import Image

# %%
#read 2749.jpg from test set
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=431x469 at 0x1FE42577CA0>

# %%
img_cat = Image.open("C:/Users/MT/Desktop/2- DL/Proje_Ödev/CNN_Proje/data/2749.jpg")

# %%
plt.imshow(img_cat)

# %%
os.listdir(train_path+'cat')[2]
# Out:
# 'cat.10.jpg'

# %%
kara = train_path+'cat'+'/cat.10.jpg'

# %%
imread(kara)
# Out:
# array([[[ 26,  30,  39],
#         [ 24,  28,  37],
#         [ 19,  23,  32],
#         ...,
#         [126, 158, 155],
#         [125, 157, 154],
#         [125, 157, 154]],
#
#        [[ 29,  33,  42],
#         [ 29,  33,  42],
#         [ 26,  30,  39],
#         ...,
#         [126, 158, 155],
#         [125, 157, 154],
#         [124, 156, 153]],
#
#        [[ 30,  34,  43],
#         [ 34,  38,  47],
#         [ 35,  39,  48],
#         ...,
#         [127, 159, 156],
#         [126, 158, 155],
#         [124, 156, 153]],
#
#        ...,
#
#        [[165, 151, 116],
#         [163, 149, 114],
#         [156, 142, 105],
#         ...,
#         [175, 171,   2],
#         [172, 167,   3],
#         [166, 161,   0]],
#
#        [[160, 146, 111],
#         [159, 145, 110],
#         [153, 139, 102],
#         ...,
#         [175, 171,   2],
#         [172, 167,   3],
#         [166, 161,   0]],
#
#        [[154, 140, 105],
#         [154, 140, 105],
#         [150, 136,  99],
#         ...,
#         [175, 171,   2],
#         [172, 167,   3],
#         [166, 161,   0]]], dtype=uint8)

# %%
kara = imread(kara)

# %%
plt.imshow(kara)

# %%
kara.shape
# Out:
# (499, 489, 3)

# %%
my_image = image.load_img(train_path+'cat'+'/cat.10.jpg',target_size=image_shape)

# %%
my_image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x202D1089B80>

# %%
type(my_image)
# Out:
# PIL.Image.Image

# %%
my_image = image.img_to_array(my_image)

# %%
type(my_image)
# Out:
# numpy.ndarray

# %%
my_image.shape
# Out:
# (128, 128, 3)

# %%
my_image = np.expand_dims(my_image, axis=0)

# %%
my_image.shape
# Out:
# (1, 128, 128, 3)

# %%
model.predict(my_image)
# Out:
# array([[0.29139525]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
val_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
# resize it as 128 * 128

# %%
# turn the image into numpy array
# Out:
# (128, 128, 3)

# %%
#reshape it as below
# Out:
# (1, 128, 128, 3)

# %%
#predict the image class with your model
# Out:
# array([[0.]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
test_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}
